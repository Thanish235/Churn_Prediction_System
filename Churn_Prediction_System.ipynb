# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Telco_customer_churn.xlsx")

# %%
df
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     Lat Long   Latitude   Longitude  Gender  ...  \
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Tenure Months'], bins=30, kde=True)
plt.xlabel("Tenure Months")
plt.ylabel("Customer Count")
plt.title("Distribution of Tenure Months Vs No of Customers")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'Churn Label', y ='Tenure Months', data = df)
plt.xlabel("Churn Label")
plt.ylabel("Tenure Months")
plt.title("Churn Vs Tenure Months")
plt.show()

# %%
df['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df[df['Churn Label']=='Yes']['Tenure Months']
# Out:
# 0        2
# 1        2
# 2        8
# 3       28
# 4       49
#         ..
# 1864    12
# 1865     9
# 1866     1
# 1867    67
# 1868     4
# Name: Tenure Months, Length: 1869, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Monthly Charges'], bins=30, kde=True)
plt.xlabel("Monthly Charges")
plt.ylabel("Customer Count")
plt.title("Distribution of Monthly Charges Vs No of Customers")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x = 'Churn Label', y ='Monthly Charges', data = df)
plt.xlabel("Churn Label")
plt.ylabel("Monthly Charges")
plt.title("Churn Vs Monthly Charges")
plt.show()

# %%
df[df['Churn Label']=='Yes']['Monthly Charges'].quantile(q = [0.25, 0.5, 0.75])
# Out:
# 0.25    56.15
# 0.50    79.65
# 0.75    94.20
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label']=='No']['Monthly Charges'].quantile(q = [0.25, 0.5, 0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
df['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df[df['Churn Label']=='No']['Monthly Charges'].describe()
# Out:
# count    5174.000000
# mean       61.265124
# std        31.092648
# min        18.250000
# 25%        25.100000
# 50%        64.425000
# 75%        88.400000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'Contract', hue='Churn Label',data = df)
plt.xlabel("Contract")
plt.ylabel("Count")
plt.title("Contract Vs Count")
plt.show()

# %% [markdown]
# Data Cleaning

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df['Total Charges'].isnull()]['Tenure Months']
# Out:
# Series([], Name: Tenure Months, dtype: int64)

# %%
df[df['Total Charges'].isnull()]['Tenure Months'].shape
# Out:
# (0,)

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'].replace(' ', np.nan))
# Out:
# /tmp/ipykernel_2318/2905419547.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Total Charges'] = pd.to_numeric(df['Total Charges'].replace(' ', np.nan))

# %%
df['Total Charges'] = df['Total Charges'].fillna(0)

# %%
df['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# Data Leakage - Model accidentally gets in formation about the answer

# %%
drop_columns = ['CustomerID',
                'Count',
                'Country',
                'State',
                'Zip Code',
                'Lat Long',
                'Latitude',
                'Longitude',
                'Churn Label',
                'Churn Score',
                'CLTV',
                'Churn Reason']

# %%
df = df.drop(columns = drop_columns)

# %%
df
# Out:
#               City  Gender Senior Citizen Partner Dependents  Tenure Months  \
# 0      Los Angeles    Male             No      No         No              2
# 1      Los Angeles  Female             No      No        Yes              2
# 2      Los Angeles  Female             No      No        Yes              8
# 3      Los Angeles  Female             No     Yes        Yes             28
# 4      Los Angeles    Male             No      No        Yes             49
# ...            ...     ...            ...     ...        ...            ...
# 7038       Landers  Female             No      No         No             72
# 7039      Adelanto    Male             No     Yes        Yes             24
# 7040         Amboy  Female             No     Yes        Yes             72
# 7041  Angelus Oaks  Female             No     Yes        Yes             11
# 7042  Apple Valley    Male             No      No         No             66
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df_encoded = pd.get_dummies(df, drop_first = True)

# %%
df_encoded.head()
# Out:
#    Tenure Months  Monthly Charges  Total Charges  Churn Value  City_Acton  \
# 0              2            53.85         108.15            1       False
# 1              2            70.70         151.65            1       False
# 2              8            99.65         820.50            1       False
# 3             28           104.80        3046.05            1       False
# 4             49           103.70        5036.30            1       False
#
#    City_Adelanto  City_Adin  City_Agoura Hills  City_Aguanga  City_Ahwahnee  \
# 0          False      False              False         False          False
# 1          False      False              False         False          False
# 2          False      False              False         False          False
# 3          False      False              False         False          False
# 4          False      False              False         False          False
#
#    ...  Streaming TV_No internet service  Streaming TV_Yes  \
# ...

# %%
df_encoded.shape
# Out:
# (7043, 1159)

# %%
df = df.drop(columns = ['City'])

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
# ...

# %%
df_encoded = pd.get_dummies(df, drop_first = True)

# %%
df_encoded.shape
# Out:
# (7043, 31)

# %%
df_encoded
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Value  Gender_Male  \
# 0                 2            53.85         108.15            1         True
# 1                 2            70.70         151.65            1        False
# 2                 8            99.65         820.50            1        False
# 3                28           104.80        3046.05            1        False
# 4                49           103.70        5036.30            1         True
# ...             ...              ...            ...          ...          ...
# 7038             72            21.15        1419.40            0        False
# 7039             24            84.80        1990.50            0         True
# 7040             72           103.20        7362.90            0        False
# 7041             11            29.60         346.45            0        False
# 7042             66           105.65        6844.50            0         True
#
# ...

# %%
X = df_encoded.drop(columns = ['Churn Value'], axis = 1)

# %%
X
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Gender_Male  \
# 0                 2            53.85         108.15         True
# 1                 2            70.70         151.65        False
# 2                 8            99.65         820.50        False
# 3                28           104.80        3046.05        False
# 4                49           103.70        5036.30         True
# ...             ...              ...            ...          ...
# 7038             72            21.15        1419.40        False
# 7039             24            84.80        1990.50         True
# 7040             72           103.20        7362.90        False
# 7041             11            29.60         346.45        False
# 7042             66           105.65        6844.50         True
#
#       Senior Citizen_Yes  Partner_Yes  Dependents_Yes  Phone Service_Yes  \
# 0                  False        False           False               True
# ...

# %%
Y = df_encoded['Churn Value']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    0
# 7042    0
# Name: Churn Value, Length: 7043, dtype: int64

# %% [markdown]
# ML implementation

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 42)

# %%
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
Y_test
# Out:
# 185     1
# 2715    0
# 3825    0
# 1807    1
# 132     1
#        ..
# 6366    0
# 315     1
# 2439    0
# 5002    0
# 1161    1
# Name: Churn Value, Length: 1409, dtype: int64

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(accuracy_score(Y_test, y_pred))
# Out:
# 0.7856635911994322

# %%
print(confusion_matrix(Y_test, y_pred))
# Out:
# [[902 107]
#  [195 205]]

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# Approach 1 - Handle Class Imbalance

# %%
balanced_model = RandomForestClassifier(n_estimators = 100, random_state = 42, class_weight = 'balanced')

# %%
balanced_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred_balanced = balanced_model.predict(X_test)

# %%
print(accuracy_score(Y_test, y_pred_balanced))
# Out:
# 0.7920511000709723

# %%
print(confusion_matrix(Y_test, y_pred_balanced))
# Out:
# [[907 102]
#  [191 209]]

# %%
print(classification_report(Y_test, y_pred_balanced))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1009
#            1       0.67      0.52      0.59       400
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# Approach 2 - Hyperparameter Tuning

# %%
tuned_model = RandomForestClassifier(n_estimators = 100, max_depth = 10, random_state = 42, class_weight = 'balanced')
tuned_model.fit(X_train, Y_train)
y_pred_tuned = tuned_model.predict(X_test)
print(accuracy_score(Y_test, y_pred_tuned))
print(confusion_matrix(Y_test, y_pred_tuned))
print(classification_report(Y_test, y_pred_tuned))
# Out:
# 0.7757274662881476
# [[792 217]
#  [ 99 301]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83      1009
#            1       0.58      0.75      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.73      0.77      0.74      1409
# weighted avg       0.80      0.78      0.78      1409

# %%
tuned_model_1 = RandomForestClassifier(n_estimators = 320, max_depth = 8, random_state = 42, class_weight = 'balanced')
tuned_model_1.fit(X_train, Y_train)
y_pred_tuned = tuned_model_1.predict(X_test)
print(accuracy_score(Y_test, y_pred_tuned))
print(confusion_matrix(Y_test, y_pred_tuned))
print(classification_report(Y_test, y_pred_tuned))
# Out:
# 0.7601135557132718
# [[757 252]
#  [ 86 314]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1009
#            1       0.55      0.79      0.65       400
#
#     accuracy                           0.76      1409
#    macro avg       0.73      0.77      0.73      1409
# weighted avg       0.80      0.76      0.77      1409

# %% [markdown]
# OPTIONAL

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# %%
y_prob = tuned_model_1.predict_proba(X)

# %%
churn_probabilities = y_prob[:, 1]

# %%
#fpr, tpr, threshold = roc_curve(Y_test, churn_probabilities)

# %%
#auc_score = roc_auc_score(Y_test, churn_probabilities)
#print(auc_score)

# %% [markdown]
# ML -> 1.Imbalance, 2.Hyperparameter Tuning, 3. Feature Selection -> To maximise Recall

# %% [markdown]
# **Customer Segmentation**

# %%
segmentation_data=pd.DataFrame({
    "Tenure Months":X['Tenure Months'],
    "Monthly Charges":X['Monthly Charges'],
    "Total Charges":X['Total Charges'],
    "Churn Probability":churn_probabilities
})

# %% [markdown]
# Implementation of K-Means

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(segmentation_data)
scaler
# Out:
# StandardScaler()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for k in range(1,16):
  kmeans = KMeans(n_clusters = k, random_state = 42)
  kmeans.fit(scaled_data)
  wcss.append(kmeans.inertia_)
  plt.figure(figsize=(10,8))
plt.plot(range(1,16), wcss, marker="o")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Curve")
plt.show()

# %%
kmeans=KMeans(n_clusters=3, random_state=42)

# %%
clusters = kmeans.fit_predict(scaled_data)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability
# 0                 2            53.85         108.15           0.655534
# 1                 2            70.70         151.65           0.781529
# 2                 8            99.65         820.50           0.750977
# 3                28           104.80        3046.05           0.460726
# 4                49           103.70        5036.30           0.393320
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.011545
# 7039             24            84.80        1990.50           0.139236
# 7040             72           103.20        7362.90           0.107182
# 7041             11            29.60         346.45           0.438340
# 7042             66           105.65        6844.50           0.259617
#
# [7043 rows x 4 columns]

# %%
segmentation_data['Cluster'] = clusters

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15           0.655534
# 1                 2            70.70         151.65           0.781529
# 2                 8            99.65         820.50           0.750977
# 3                28           104.80        3046.05           0.460726
# 4                49           103.70        5036.30           0.393320
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.011545
# 7039             24            84.80        1990.50           0.139236
# 7040             72           103.20        7362.90           0.107182
# 7041             11            29.60         346.45           0.438340
# 7042             66           105.65        6844.50           0.259617
#
#       Cluster
# 0           2
# 1           2
# 2           2
# 3           1
# 4           1
# ...       ...
# ...

# %%
Cluster_summary = segmentation_data.groupby('Cluster').mean()

# %%
Cluster_summary
# Out:
#          Tenure Months  Monthly Charges  Total Charges  Churn Probability
# Cluster
# 0            32.995514        32.163392    1069.280350           0.145852
# 1            58.451748        90.531515    5288.146900           0.265643
# 2            10.889472        71.275496     872.861634           0.695101

# %%
Cluster_names={
    0:'Budget Loyal Customers',
    1:'High Risk New Customers',
    2:'Premium Loyal Customers'
}

# %%
segmentation_data['Cluster Segment'] = segmentation_data['Cluster'].map(Cluster_names)

# %%
segmentation_data
# Out:
#       Tenure Months  Monthly Charges  Total Charges  Churn Probability  \
# 0                 2            53.85         108.15           0.655534
# 1                 2            70.70         151.65           0.781529
# 2                 8            99.65         820.50           0.750977
# 3                28           104.80        3046.05           0.460726
# 4                49           103.70        5036.30           0.393320
# ...             ...              ...            ...                ...
# 7038             72            21.15        1419.40           0.011545
# 7039             24            84.80        1990.50           0.139236
# 7040             72           103.20        7362.90           0.107182
# 7041             11            29.60         346.45           0.438340
# 7042             66           105.65        6844.50           0.259617
#
#       Cluster          Cluster Segment
# 0           2  Premium Loyal Customers
# ...

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Tenure Months', y='Monthly Charges', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
plt.xlabel('Tenure Months')
plt.ylabel('Monthly Charges')
plt.title('Customer Segmentation')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Tenure Months', y='Churn Probability', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
# Out:
# <Axes: xlabel='Tenure Months', ylabel='Churn Probability'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Monthly Charges', y='Churn Probability', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
# Out:
# <Axes: xlabel='Monthly Charges', ylabel='Churn Probability'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Total Charges', y='Churn Probability', hue='Cluster Segment', data=segmentation_data, palette='Spectral')
# Out:
# <Axes: xlabel='Total Charges', ylabel='Churn Probability'>

# %% [markdown]
# Data Cleaning -> Encoding -> EDA -> Feature Selection -> Train Test Split -> Random Forest(Hyperparameter Tuning, Feature Importance, Feature Selection)-> Cross Validation -> ROC - AUC Score -> Customer Segmentation using K-Means -> K-Optimum Value ->Visualization -> Business Insights
